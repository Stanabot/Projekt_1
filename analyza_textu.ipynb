# %%
# dolpň hlavičku dle zadání projektu
# ještě to 
# třetí řádek

# %%
"""
projekt_1.py: první projekt do Engeto Online Python Akademie

autor: Stanislava Jahodová
email: stanislavajahodova@gmail.com
"""

# %%
TEXTS = [
    '''Situated about 10 miles west of Kemmerer,
    Fossil Butte is a ruggedly impressive
    topographic feature that rises sharply
    some 1000 feet above Twin Creek Valley
    to an elevation of more than 7500 feet
    above sea level. The butte is located just
    north of US 30 and the Union Pacific Railroad,
    which traverse the valley.''',
    '''At the base of Fossil Butte are the bright
    red, purple, yellow and gray beds of the Wasatch
    Formation. Eroded portions of these horizontal
    beds slope gradually upward from the valley floor
    and steepen abruptly. Overlying them and extending
    to the top of the butte are the much steeper
    buff-to-white beds of the Green River Formation,
    which are about 300 feet thick.''',
    '''The monument contains 8198 acres and protects
    a portion of the largest deposit of freshwater fish
    fossils in the world. The richest fossil fish deposits
    are found in multiple limestone layers, which lie some
    100 feet below the top of the butte. The fossils
    represent several varieties of perch, as well as
    other freshwater genera and herring similar to those
    in modern oceans. Other fish such as paddlefish,
    garpike and stingray are also present.'''
]
# 2) Ověření registrace:

uzivatele = {
    "bob":"123",
    "ann":"pass123",
    "mike":"password123",
    "liz":"pass123"
}

jmeno = input("Zadej přihlašovací jmého: ")
print(f"uživatelské jméno: {jmeno}")

autorizovan = False

if jmeno in uzivatele:
    heslo = input("Zadej heslo: ")
    print(f"heslo: {heslo}")
    if heslo == uzivatele[jmeno]:   
        autorizovan = True
    else:
        print("nesprávné heslo")
else:
    print("neregistrovaný uživatel")

if not autorizovan:
    print("ukončuji program")
    exit()

else: 
    oddelovac = "-" * 42
    pocet_textu = len(TEXTS) 
    print(f"{oddelovac}\nVítej v naší aplikaci, {jmeno.title()}.\n{oddelovac}")
    print(f"Máme pro tebe na výběr {len(TEXTS)} texty k analýze.\n{oddelovac}")

# 2) Výběr textu k analýze:

print(f"Vyber si (celé) číslo od 1 do {len(TEXTS)}:   ",end="")
volba = input(f"Zadej číslo 1-{len(TEXTS)}:")

if not volba.isdigit(): 
    print("není číslo, ukončuji program")

elif int(volba) < 1 or int(volba) > len(TEXTS):
    print("číslo je mimo interval, ukončuji program.")

else:
    print(int(volba),oddelovac, sep="\n")

# 3) Četnosti slov: 

text = TEXTS[int(volba)-1]

vycistena_slova = [slovo.strip(",.-;'")for slovo in text.split()]
pocet_slov = len(vycistena_slova)

kapitalky = [slovo for slovo in vycistena_slova if slovo[0].isupper()]
pocet_kapitalky = len(kapitalky)

vsechna_velka = [slovo for slovo in vycistena_slova if slovo.isupper()] 
pocet_vsechna_velka = len(vsechna_velka) 

vsechna_mala = [slovo for slovo in vycistena_slova if slovo.islower()]
pocet_vsechna_mala = len(vsechna_mala)

cisla = [slovo for slovo in vycistena_slova if slovo.isdigit()]
pocet_cisel = len(cisla)

soucet_cisel = 0
for cislo in cisla:
    soucet_cisel += int(cislo)



print("Ve zvoleném textu je:\n")
print(f"celkový pocet slov: {pocet_slov}")
print(f"pocet slov začínajících velkým písmenem: {pocet_kapitalky}")
print(f"pocet slov psaných velkými písmeny: {pocet_vsechna_velka}")
print(f"pocet slov psaných malými písmeny: {pocet_vsechna_mala}")
print(f"pocet cisel: {pocet_cisel}",)
print(f"suma všech čísel: {soucet_cisel}",)

# Četnosti délek slov:
